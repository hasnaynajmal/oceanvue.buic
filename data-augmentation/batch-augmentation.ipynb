# %% [markdown]
# Loading Libraries

# %%
import os
import numpy as np
import librosa
import soundfile as sf
from scipy.signal import convolve, butter, lfilter

# %% [markdown]
# Defining Augmentation Functions

# %%
def add_white_noise(signal, noise_percentage_factor):
    noise = np.random.normal(0, signal.std(), signal.size)
    augmented_signal = signal + noise * noise_percentage_factor
    return augmented_signal

def time_stretch(audio, factor=0.95):
    # audio: Original audio
    # factor: Time stretching factor (e.g., 0.8 for 80% speed)
    augmented_audio = librosa.effects.time_stretch(audio, rate = factor)    
    return augmented_audio


def apply_bandpass_filter(audio, lowcut, highcut, fs):
    # audio: Original audio
    # lowcut: Low cutoff frequency of the filter
    # highcut: High cutoff frequency of the filter
    # fs: Sampling frequency
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    # Design bandpass filter
    b, a = butter(4, [low, high], btype='band')
    # Apply the filter
    augmented_audio = lfilter(b, a, audio)
    return augmented_audio

#time shifting
def time_shift(audio, shift_amount, fs):
    # audio: Original audio
    # shift_amount: Amount of time shift in seconds
    # fs: Sampling frequency
    shift_samples = int(shift_amount * fs)
    if shift_samples > 0:
        augmented_audio = np.pad(audio[:-shift_samples], (shift_samples, 0), 'constant')
    else:
        augmented_audio = np.pad(audio[-shift_samples:], (0, -shift_samples), 'constant')
    return augmented_audio

# %% [markdown]
# Parameters for augmentation

# %%
# Define parameters for bandpass filter
lowcut = 500  # Low cutoff frequency in Hz
highcut = 2000  # High cutoff frequency in Hz

# Define time shift amount in seconds
shift_amount = 1.0  # Shift by 1 second

stretch_rate = 0.95

# %% [markdown]
# Augmentation Part

# %%
# Set the path to the root directory containing category folders
root_path = 'D:/ocean-vue/Augmented Dataset/'

# Get the list of category folders
categories = ['Cargo', 'Passenger', 'Tanker', 'Tug']

# Iterate through each category
for category in categories:
    category_path = os.path.join(root_path, category)
    
    # Iterate through each subfolder within the category
    subfolders = os.listdir(category_path)
    for subfolder in subfolders:
        subfolder_path = os.path.join(category_path, subfolder)
        
        # Iterate through each audio file in the subfolder
        audio_files = os.listdir(subfolder_path)
        for audio_file in audio_files:
            audio_path = os.path.join(subfolder_path, audio_file)
            
            # Load the audio file
            audio, sr = librosa.load(audio_path, sr=None)

            print('Audio File Being Iterated : ', audio_path)
            
            # Apply augmentation
            augmented_audio = add_white_noise(audio, 0.1) # Example augmentation
            augmented_audio = apply_bandpass_filter(augmented_audio, lowcut, highcut, sr)  # Example augmentation
            augmented_audio = time_shift(augmented_audio,  shift_amount, sr)  # Example augmentation
            augmented_audio = time_stretch(augmented_audio, stretch_rate)  # Example augmentation
            
            # Create a new folder for augmented data
            new_folder_id = len(os.listdir(category_path)) + 1
            new_folder_path = os.path.join(category_path, str(new_folder_id))
            os.makedirs(new_folder_path)
            
            # Save the augmented audio
            new_audio_path = os.path.join(new_folder_path, f'{new_folder_id}.wav')
            sf.write(new_audio_path, augmented_audio, sr)
# Out:
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\1\1.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\10\10.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\11\11.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\12\12.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\13\13.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\14\14.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\15\15.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\16\16.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\17\17.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\18\18.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\19\19.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\2\2.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\20\20.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\21\21.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\22\22.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\23\23.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\24\24.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\25\25.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\26\26.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\27\27.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\28\28.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\29\29.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\3\3.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\30\30.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\31\31.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\32\32.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\33\33.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\34\34.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\35\35.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\36\36.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\37\37.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\38\38.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\39\39.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\4\4.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\40\40.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\41\41.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\42\42.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\43\43.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\44\44.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\45\45.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\46\46.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\47\47.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\48\48.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\49\49.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\5\5.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\50\50.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\51\51.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\52\52.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\53\53.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\54\54.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\55\55.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\56\56.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\57\57.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\58\58.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\59\59.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\6\6.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\60\60.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\61\61.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\62\62.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\63\63.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\64\64.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\65\65.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\66\66.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\67\67.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\68\68.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\69\69.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\7\7.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\8\8.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Cargo\9\9.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\1\1.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\10\10.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\11\11.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\12\12.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\13\13.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\14\14.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\15\15.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\16\16.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\17\17.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\18\18.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\19\19.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\2\2.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\20\20.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\21\21.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\22\22.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\23\23.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\24\24.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\25\25.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\26\26.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\27\27.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\28\28.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\29\29.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\3\3.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\30\30.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\31\31.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\32\32.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\33\33.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\34\34.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\35\35.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\36\36.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\37\37.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\38\38.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\39\39.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\4\4.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\40\40.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\41\41.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\42\42.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\43\43.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\44\44.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\45\45.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\46\46.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\47\47.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\48\48.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\49\49.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\5\5.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\50\50.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\51\51.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\52\52.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\53\53.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\54\54.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\55\55.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\56\56.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\57\57.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\58\58.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\59\59.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\6\6.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\60\60.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\61\61.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\62\62.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\63\63.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\64\64.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\65\65.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\66\66.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\67\67.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\68\68.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\69\69.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\7\7.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\8\8.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Passenger\9\9.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\1\1.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\10\10.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\11\11.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\12\12.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\13\13.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\14\14.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\15\15.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\16\16.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\17\17.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\18\18.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\19\19.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\2\2.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\20\20.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\21\21.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\22\22.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\23\23.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\24\24.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\25\25.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\26\26.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\27\27.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\28\28.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\29\29.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\3\3.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\30\30.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\31\31.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\32\32.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\33\33.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\34\34.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\35\35.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\36\36.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\37\37.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\38\38.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\39\39.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\4\4.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\40\40.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\41\41.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\42\42.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\43\43.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\44\44.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\45\45.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\46\46.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\47\47.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\48\48.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\49\49.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\5\5.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\50\50.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\51\51.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\52\52.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\53\53.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\54\54.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\55\55.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\56\56.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\57\57.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\58\58.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\59\59.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\6\6.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\60\60.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\61\61.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\62\62.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\63\63.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\64\64.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\65\65.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\66\66.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\67\67.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\68\68.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\69\69.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\7\7.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\8\8.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tanker\9\9.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\1\1.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\10\10.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\11\11.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\12\12.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\13\13.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\14\14.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\15\15.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\16\16.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\17\17.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\18\18.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\19\19.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\2\2.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\20\20.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\21\21.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\22\22.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\23\23.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\24\24.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\25\25.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\26\26.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\27\27.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\28\28.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\29\29.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\3\3.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\30\30.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\31\31.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\32\32.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\33\33.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\34\34.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\35\35.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\36\36.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\37\37.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\38\38.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\39\39.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\4\4.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\40\40.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\41\41.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\42\42.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\43\43.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\44\44.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\45\45.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\46\46.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\47\47.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\48\48.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\49\49.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\5\5.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\50\50.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\51\51.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\52\52.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\53\53.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\54\54.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\55\55.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\56\56.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\57\57.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\58\58.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\59\59.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\6\6.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\60\60.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\61\61.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\62\62.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\63\63.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\64\64.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\65\65.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\66\66.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\67\67.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\68\68.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\69\69.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\7\7.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\8\8.wav
# Audio File Being Iterated :  D:/ocean-vue/Augmented Dataset/Tug\9\9.wav
